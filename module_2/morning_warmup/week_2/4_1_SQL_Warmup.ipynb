# %% [markdown]
# ### Import packages

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ### Connect to database - there are two relevant tables ('author' and 'books')

# %%
conn = sqlite3.connect('amazon_db.db')
c = conn.cursor()

# %%
c.execute("""SELECT * FROM books
LIMIT 5; """)

# %%
df = pd.DataFrame(c.fetchall())
df.columns = [i[0] for i in c.description]
df
# Out:
#                                 books num_copies
# 0         A Elephant Ate Under A Fish    4226324
# 1         A Boy Jumped Outside A Lake    4048899
# 2       One Man Hopped Under The Tree     774329
# 3  A Person Threw Behind The Notebook    1359606
# 4     The Tree Ran Through A Mountain    4703380

# %%
c.execute("""SELECT * FROM author
LIMIT 5; """);

# %%
df = pd.DataFrame(c.fetchall())
df.columns = [i[0] for i in c.description]
df
# Out:
#              author                                book
# 0      David Taylor         A Guy Dove Outside The Desk
# 1    Sidney Osborne        A Fish Hopped Through A Lake
# 2     Robert Martin     The Woman Winced Outside A Desk
# 3      Greg Simpson  A Banana Winced Outside The Banana
# 4  Edgar Williamson      A Person Ate Behind The Potato

# %% [markdown]
# ### Use SQL to answer the following questions:

# %% [markdown]
# 1. How many rows are in the 'author' table?
#
# 2. How many authors have the first name 'David'?
#
# 3. How many books did each author write?
#
# 4. Use both the author table and books table to answer: how many copies were sold by authors named David
#
#
#     a. how many copies for each of the Davids
#
#
#     b. how many copies in total for all Davids

# %%
c.execute("""SELECT count(*) FROM author """)

# %%
print(c.fetchall())
# Out:
# [(100000,)]

# %% [markdown]
# There are 100,000 rows in the 'author' table

# %%
c.execute("""SELECT count(*) 
              FROM author 
              WHERE author 
              LIKE 'David%' """)

# %%
print(c.fetchall())
# Out:
# [(1335,)]

# %%
c.execute(""" SELECT author, count(*) 
    FROM author 
    GROUP BY author """)

# %%
print(c.fetchall())
# Out:
# [('Aaron Agrela', 1), ('Aaron Allen', 1), ('Aaron Allman', 1), ('Aaron Anderson', 1), ('Aaron Baez', 1), ('Aaron Bean', 1), ('Aaron Becker', 1), ('Aaron Blain', 1), ('Aaron Blair', 1), ('Aaron Blanch', 1), ('Aaron Blanchard', 1), ('Aaron Boehman', 1), ('Aaron Bracero', 1), ('Aaron Broadwater', 1), ('Aaron Brown', 1), ('Aaron Buckley', 1), ('Aaron Burbridge', 1), ('Aaron Campbell', 1), ('Aaron Carpenter', 1), ('Aaron Cashman', 1), ('Aaron Caskey', 1), ('Aaron Charlton', 1), ('Aaron Chong', 1), ('Aaron Cobb', 1), ('Aaron Coppenger', 1), ('Aaron Coulter', 1), ('Aaron Doten', 1), ('Aaron Duarte', 1), ('Aaron Duncan', 1), ('Aaron Enck', 1), ('Aaron Estes', 1), ('Aaron Evans', 2), ('Aaron Ferreira', 1), ('Aaron Fisher', 1), ('Aaron Fowler', 1), ('Aaron Frain', 1), ('Aaron Galvin', 1), ('Aaron Germy', 1), ('Aaron Gill', 1), ('Aaron Gomez', 1), ('Aaron Hafenstein', 1), ('Aaron Hall', 2), ('Aaron Harris', 1), ('Aaron Harwell', 1), ('Aaron Hatton', 1), ('Aaron Heaney', 1), ('Aaron Hedrick', 1), ('Aaron Hite', 1), ('Aaron Hopkins', 1), ('Aaron Hunt', 1), ('Aaron Jarmon', 1), ('Aaron Johnson', 2), ('Aaron Jones', 1), ('Aaron Juelfs', 1), ('Aaron Keisel', 1), ('Aaron Kenney', 1), ('Aaron Kerr', 1), ('Aaron Kitanik', 1), ('Aaron Latham', 1), ('Aaron Leblanc', 1), ('Aaron Lee', 1), ('Aaron Lehman', 1), ('Aaron Lindsey', 1), ('Aaron Llanas', 1), ('Aaron Maresca', 1), ('Aaron Mcbride', 1), ('Aaron Mckinley', 1), ('Aaron Miele', 1), ('Aaron Mintz', 1), ('Aaron Molina', 1), ('Aaron Morgan', 1), ('Aaron Niess', 1), ('Aaron Nordstrom', 1), ('Aaron Ober', 1), ('Aaron Panahon', 1), ('Aaron Patterson', 1), ('Aaron Plourd', 1), ('Aaron Powers', 1), ('Aaron Quintanilla', 1), ('Aaron Quiroz', 1), ('Aaron Ramirez', 1), ('Aaron Ramos', 1), ('Aaron Reibert', 1), ('Aaron Repinski', 1), ('Aaron Rogers', 1), ('Aaron Ruiz', 1), ('Aaron Sandoval', 1), ('Aaron Scherer', 1), ('Aaron Schmidt', 1), ('Aaron Seeger', 1), ('Aaron Skidmore', 1), ('Aaron Smith', 1), ('Aaron Spicer', 1), ('Aaron Stanley', 1), ('Aaron Steffen', 1), ('Aaron Stewart', 2), ('Aaron Stillman', 1), ('Aaron Sutherland', 1), ('Aaron Swift', 1), ('Aaron Taylor', 3), ('Aaron Thomas', 2), ('Aaron Trappey', 1), ('Aaron Tryon', 1), ('Aaron Valenzuela', 1), ('Aaron Vanness', 1), ('Aaron Vasser', 1), ('Aaron Vert', 1), ('Aaron Vincente', 1), ('Aaron Walk', 1), ('Aaron Wall', 1), ('Aaron Wattles', 1), ('Aaron Werre', 1), ('Aaron Wescott', 1), ('Aaron Whaley', 1), ('Aaron White', 1), ('Aaron Williams', 1), ('Aaron Wilson', 1), ('Aaron Wolff', 1), ('Aaron Worthington', 1), ('Aaron Young', 2), ('Abbey Kilian', 1), ('Abbey Nelson', 1), ('Abbey Sowers', 1), ('Abbie Alway', 1), ('Abbie Gutierrez', 1), ('Abbie Mcculloch', 1), ('Abby Gibson', 1), ('Abby Hernandez', 1), ('Abby Holmes', 1), ('Abby Rosado', 1), ('Abby Stoner', 1), ('Abby Wireman', 1), ('Abdul Barksdale', 1), ('Abdul Dealba', 1), ('Abdul Garvey', 1), ('Abdul Murphy', 1), ('Abdul Noy', 1), ('Abdul Welker', 1), ('Abdul Whitted', 1), ('Abe Robbins', 1), ('Abel Archila', 1), ('Abel Blevins', 1), ('Abel Carpenter', 1), ('Abel Colvin', 1), ('Abel Crosby', 1), ('Abel Dahl', 1), ('Abel Ellis', 1), ('Abel James', 1), ('Abel Luckow', 1), ('Abel Maestas', 1), ('Abel Parker', 1), ('Abel Rigby', 1), ('Abel Wilenkin', 1), ('Abel Woodson', 1), ('Abigail Acosta', 1), ('Abigail Adams', 1), ('Abigail Atwood', 1), ('Abigail Baker', 1), ('Abigail Carr', 1), ('Abigail Casteel', 1), ('Abigail Cohen', 1), ('Abigail Gooding', 1), ('Abigail Harper', 1), ('Abigail Jones', 1), ('Abigail King', 1), ('Abigail Martin', 1), ('Abigail Moore', 1), ('Abigail Ross', 1), ('Abigail Sims', 1), ('Abigail Stanback', 1), ('Abigail Swenson', 1), ('Abigail Williams', 1), ('Abigail Wiser', 1), ('Abraham Bolebruch', 1), ('Abraham Carlson', 1), ('Abraham Charley', 1), ('Abraham Childers', 1), ('Abraham Fish', 1), ('Abraham Furrow', 1), ('Abraham Giebner', 1), ('Abraham Girard', 1), ('Abraham Gongalves', 1), ('Abraham Griffis', 1), ('Abraham Hill', 1), ('Abraham Kaiser', 1), ('Abraham Keen', 1), ...
